# %%
# !pip install pyperclip // 마우스, 키보드 조작
# !pip install pyautogui // 매크로
# !pip install opencv-python  // 이미지 인식
import pyperclip
import pyautogui
import time
# 네이버 블로그란에서 내블로그까지 들어간 후 글자를 입력하는 매로로

A = pyautogui.locateCenterOnScreen("1.png", confidence = 0.8) # confidence: 80%만 맞으면 가지고 와라
pyautogui.click(A)
time.sleep(2)

A = pyautogui.locateCenterOnScreen("2.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

A = pyautogui.locateCenterOnScreen("3.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

A = pyautogui.locateCenterOnScreen("4.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

text = "우와 신기하다!!"
pyperclip.copy(text) # Ctrl C
pyautogui.hotkey("ctrl", "v") # Ctrl V

# %%
# 개인 연습: 크롬창을 여는 것부터 로그인 ~ 블로그에서 내용 입력하기 까지 매크로로 하기 
import pyperclip
import pyautogui
import time
import undetected_chromedriver as uc
# 네이버 열기
driver = uc.Chrome()
driver.get("https://www.naver.com/")
time.sleep(2)

# 창 크기 크게 하기
A = pyautogui.locateCenterOnScreen("big.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

# 로그인 누르기
A = pyautogui.locateCenterOnScreen("login1.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

# 아이디 입력
text1 = "yunminsuft"
pyperclip.copy(text1)
pyautogui.hotkey("ctrl", "v")

# 비밀번호 입력
A = pyautogui.locateCenterOnScreen("pw.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)
text2 = "yms20011221ft!"
pyperclip.copy(text2)
pyautogui.hotkey("ctrl", "v")

# 로그인 들어가기
A = pyautogui.locateCenterOnScreen("login2.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

# 로그인 자동저장 사용하지 않음으로 표시
A = pyautogui.locateCenterOnScreen("no.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

# 블로그 버튼
A = pyautogui.locateCenterOnScreen("1.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

# 내 블로그 버튼이 나올 떄 까지 아래로 스크롤
while True:
    try:
        A = pyautogui.locateCenterOnScreen("2.png", confidence = 0.8)
        break
    except:
        pyautogui.scroll(-300)
        time.sleep(2)
pyautogui.click(A)
time.sleep(2)

# 글쓰기 버튼이 나올 떄 까지 아래로 스크롤
while True:
    try:
        A = pyautogui.locateCenterOnScreen("3.png", confidence = 0.8)
        break
    except:
        pyautogui.scroll(-300)
        time.sleep(2)
pyautogui.click(A)
time.sleep(2)

# 도움말 없애기
time.sleep(2)
A = pyautogui.locateCenterOnScreen("no2.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

# 내용 입력 클릭
A = pyautogui.locateCenterOnScreen("4.png", confidence = 0.8)
pyautogui.click(A)
time.sleep(2)

# 내용 입력하기
text = "매크로 성공!"
pyperclip.copy(text)
pyautogui.hotkey("ctrl", "v")
